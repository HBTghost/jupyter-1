# %%
from collections import defaultdict
import queue
# f = open("input.txt", "r")
# data = eval(f.read())
# f.close()
data = [[8],[1,8],[0,2],[1,10],[4,11],[3,5],[4,6],[5],[15],[0,9,16],[8],[2,18],[19, 3],[13],[12,14,21],[13,15],[7,14,23],[8,17,24],[16],[10,19],[11,18,20],[19,28],[13,22],[21],[15,31],[16,25],[24,26],[25,27],[26,35],[20,29],[28,30],[29,31],[23,30],[33,40],[32,34],[33,35],[27,34,36],[35,37],[36],[39,46],[38,47],[32,48],[42,49],[41,43,50],[42,44,51],[43,45],[44,46,53],[38,45],[39,55],[40,56],[41,50],[42,49],[43,59],[53],[45,52,61],[62],[47,63],[48,57],[56,58],[57,59],[51,58,60],[59],[53],[54,63],[55,62],[61]]
data = [sorted(x) for x in data]

class Maze:
  def __init__(self, data):
    self.edge = data[0][0]
    self.size = self.edge**2
    self.start = 0
    self.goal = data[-1][0]
    self.graph = data[1:-1]

  def DLS(self, depth):
    frontier_nodes = [self.start]
    visited_nodes = []
    # path_to_nodes = {self.start: []}
    path = [self.start]

    while len(frontier_nodes) > 0:
      current_node = frontier_nodes.pop()
      depth_of_current_node = len(path_to_nodes[current_node]) + 1
      visited_nodes.append(current_node)
      if current_node == self.goal:
        return True, visited_nodes, path_to_nodes[self.goal]
      if depth_of_current_node < depth:
        current_node_successors = self.graph[current_node][::-1]
        for successor in current_node_successors:
          if not successor in path_to_nodes[current_node]:
            path_to_nodes[successor] = path_to_nodes[current_node][:]
            path_to_nodes[successor].append(current_node)
            frontier_nodes.append(successor)
    return False, visited_nodes, path_to_nodes

  def DLS_vip(self, depth):
    frontier = [self.start]
    visited = []
    path = []
    while len(frontier) > 0:
      cur = frontier.pop()
      visited.append(cur)
      path.append(cur)
      if cur == self.goal:
        return True, visited, path
      if len(path) < depth:
        successors = self.graph[cur][::-1]
        for x in successors:
          if not x in path:
            frontier.append(x)
        if len(successors) == 0:
          path.pop()
      else:
        path.pop()
    return False, visited, path

  def DLS1(self, start, goal, graph, limit_length):
    explored_nodes = []
    paths = defaultdict(list)
    frontier = [start]

    while len(frontier) > 0:
      cur = frontier.pop()
      explored_nodes.append(cur)
      length = len(paths[cur]) + 1
      if cur == goal:
        return True, explored_nodes, paths[goal]
      if length < limit_length:
        tmp = list(reversed(graph[cur]))
        for x in tmp:
          if not x in path:
            frontier.append(x)
            paths[x] = paths[cur].copy()
            paths[x].append(cur)
    return False, explored_nodes, paths

    def DLS2(self, graph, source, target, limit_depth):
      cell_visited = []
      cells_path = defaultdict(list)
      cell_frontiers = [source]

      while len(cell_frontiers) > 0:
        cell_cur = cell_frontiers.pop()
        cell_visited.append(cell_cur)
        depth = 1 + len(cells_path[cell_cur])
        if cell_cur == target:
          return True, cell_visited, cells_path[target]
        if depth < limit_depth:
          new_frontiers = graph[cell_cur]
          new_frontiers.sort(reverse=True)
          for temp in new_frontiers:
            if not temp in cell_visited:
              cell_frontiers.append(temp)
              cells_path[temp] = list(cells_path[cell_cur])
              cells_path[temp].append(cell_cur)
      return False, cell_visited, cells_path

  def IDS(self):
    found = False
    visited = []
    path = []
    times = 0
    for i in range(self.size):
      print ("Length %d:" % (i+1))
      found, visited, path = self.DLS_vip(i+1)
      # found, visited, path = self.DLS1(self.start, self.goal, self.graph, i+1)
      # found, visited, path = self.DLS2(self.graph, self.start, self.goal, i+1)
      print (visited)
      print ("#############")

      times += len(visited)
      if found:
        path.append(self.goal)
        return True, times, visited, path
    return False, times, visited, path

  def BFS(self):
    frontier = [self.start]
    visited = []
    path = {self.start: []}

    while len(frontier) > 0:
      cur = frontier.pop(0)
      visited.append(cur)
      if cur == self.goal:
        return True, len(visited), visited, path[self.goal]
      successors = self.graph[cur]
      for x in successors:
        if not x in path:
          frontier.append(x)
          path[x] = path[cur].copy()
          path[x].append(cur)
    return False, len(visited), visited, path[self.goal]
  
  def UCS1(maze, start, goal):
    explored = list()
    PQ = queue.PriorityQueue()
    PQ.put((0, start, []))        # cost, node, path
    while PQ._qsize() > 0:
        current = PQ.get()
        if current[1] == goal:
            return current[2] + [goal], explored + [goal], len(explored) + 1
        elif current[1] not in explored:
            explored.append(current[1])
        for adjacency in maze[current[1]]:
            if adjacency not in explored:
                PQ.put((current[0] + 1, adjacency, current[2] + [current[1]]))
    return "Fail", explored, len(explored)

  def UCS(self):
    explore = []
    path = {self.start: []}
    frontier = queue.PriorityQueue()
    frontier.put((0, self.start))
    while frontier._qsize() > 0:
      cur_prior, cur_node = frontier.get()
      explore.append(cur_node)
      if cur_node == self.goal:
        return True, len(explore), explore, path[self.goal]
      successors = self.graph[cur_node]
      for x in successors:
        if not x in explore:
          frontier.put((cur_prior + 1, x))
          path[x] = path[cur_node][:]
          path[x].append(cur_node)
    return False, len(explore), explore, path
        




maze = Maze(data)
res, times, visited, path = maze.IDS()

print (res)
print (times)
print (visited)
print (path)
# Out:
# Length 1:
# [0]
# #############
# Length 2:
# [0, 1, 8]
# #############
# Length 3:
# [0, 1, 2, 8, 9, 16]
# #############
# Length 4:
# [0, 1, 2, 10, 8, 9, 16, 17, 24]
# #############
# Length 5:
# [0, 1, 2, 10, 18, 8, 9, 16, 17, 24, 25]
# #############
# Length 6:
# [0, 1, 2, 10, 18, 19, 8, 9, 16, 17, 24, 25, 26]
# #############
# Length 7:
# [0, 1, 2, 10, 18, 19, 11, 20, 8, 9, 16, 17, 24, 25, 26, 27]
# #############
# Length 8:
# [0, 1, 2, 10, 18, 19, 11, 3, 20, 28, 8, 9, 16, 17, 24, 25, 26, 27, 35]
# #############
# Length 9:
# [0, 1, 2, 10, 18, 19, 11, 3, 4, 20, 28, 29, 8, 9, 16, 17, 24, 25, 26, 27, 35, 34, 36]
# #############
# Length 10:
# [0, 1, 2, 10, 18, 19, 11, 3, 4, 5, 20, 28, 29, 30, 8, 9, 16, 17, 24, 25, 26, 27, 35, 34, 33, 36, 37]
# #############
# Length 11:
# [0, 1, 2, 10, 18, 19, 11, 3, 4, 5, 6, 20, 28, 29, 30, 31, 8, 9, 16, 17, 24, 25, 26, 27, 35, 34, 33, 32, 36, 37]
# #############
# Length 12:
# ...
